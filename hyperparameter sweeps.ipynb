# %% [markdown]
# # 1. Setup

# %%
# !pip install wandb --upgrade

# workaround to fetch MNIST data
# !wget www.di.ens.fr/~lelarge/MNIST.tar.gz
# !tar -zxvf MNIST.tar.gz
# Out:
# ...
# --2021-10-10 09:21:25--  http://www.di.ens.fr/~lelarge/MNIST.tar.gz
# Resolving www.di.ens.fr (www.di.ens.fr)... 129.199.99.14
# Connecting to www.di.ens.fr (www.di.ens.fr)|129.199.99.14|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.di.ens.fr/~lelarge/MNIST.tar.gz [following]
# --2021-10-10 09:21:25--  https://www.di.ens.fr/~lelarge/MNIST.tar.gz
# Connecting to www.di.ens.fr (www.di.ens.fr)|129.199.99.14|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-gzip]
# Saving to: ‘MNIST.tar.gz.7’
#
# MNIST.tar.gz.7          [           <=>      ]  33.20M  6.35MB/s    in 5.7s
#
# 2021-10-10 09:21:32 (5.78 MB/s) - ‘MNIST.tar.gz.7’ saved [34813078]
#
# MNIST/
# MNIST/raw/
# MNIST/raw/train-labels-idx1-ubyte
# MNIST/raw/t10k-labels-idx1-ubyte.gz
# MNIST/raw/t10k-labels-idx1-ubyte
# MNIST/raw/t10k-images-idx3-ubyte.gz
# MNIST/raw/train-images-idx3-ubyte
# MNIST/raw/train-labels-idx1-ubyte.gz
# ...

# %%
import wandb

wandb.login()
# Out:
# wandb: Currently logged in as: chowk (use `wandb login --relogin` to force relogin)
# True

# %% [markdown]
# ## hyp search method
# 1. grid search : 모든 하이퍼파라메터 조합들을 사용하여 찾는 방법, computation cost가 높음
# 2. random search : 효율적인 방법, 매번 새 조합을 사용.
# 3. bayesian search : 확률적으로 메트릭을 개선할 가능성이 높은 파라메터를 선택하는 방법, 적은 수의 파라메터에는 잘 동작.

# %%
sweep_config = {
  'method': 'random'
  }

# %%
metric = {
    'name': 'loss',
    'goal': 'minimize'   
    }

sweep_config['metric'] = metric

# %% [markdown]
# ## 하이퍼 파라메터 이름 define

# %%
parameters_dict = {
    'optimizer': {
        'values': ['adam', 'sgd']
        },
    'fc_layer_size': {
        'values': [128, 256, 512]
        },
    'dropout': {
          'values': [0.3, 0.4, 0.5]
        },
    }

sweep_config['parameters'] = parameters_dict

# %%
parameters_dict.update({
    'epochs': {
        'value': 1}
    })

# %%
#random search는 분포기반의 선택을 하기 때문에, 구체적으로 분포를 정해주기 위해서는  distribution에 선언해 줄 수가 있음
import math

parameters_dict.update({
    'learning_rate': {
        # a flat distribution between 0 and 0.1
        'distribution': 'uniform',
        'min': 0,
        'max': 0.1
      },
    'batch_size': {
        # integers between 32 and 256
        # with evenly-distributed logarithms 
        'distribution': 'q_log_uniform',
        'q': 1,
        'min': math.log(32),
        'max': math.log(256),
      }
    })

# %%
import pprint

pprint.pprint(sweep_config)
# Out:
# {'method': 'random',
#  'metric': {'goal': 'minimize', 'name': 'loss'},
#  'parameters': {'batch_size': {'distribution': 'q_log_uniform',
#                                'max': 5.545177444479562,
#                                'min': 3.4657359027997265,
#                                'q': 1},
#                 'dropout': {'values': [0.3, 0.4, 0.5]},
#                 'epochs': {'value': 1},
#                 'fc_layer_size': {'values': [128, 256, 512]},
#                 'learning_rate': {'distribution': 'uniform',
#                                   'max': 0.1,
#                                   'min': 0},
#                 'optimizer': {'values': ['adam', 'sgd']}}}

# %% [markdown]
# # 2. Initialize the Sweep

# %%
sweep_id = wandb.sweep(sweep_config, project="pytorch-sweeps-demo")
# Out:
# Create sweep with ID: k9vnqmd5
# Sweep URL: https://wandb.ai/chowk/pytorch-sweeps-demo/sweeps/k9vnqmd5

# %%
import torch
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
from torchvision import datasets, transforms

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def train(config=None):
    # Initialize a new wandb run
    with wandb.init(config=config):
        # If called by wandb.agent, as below,
        # this config will be set by Sweep Controller
        config = wandb.config

        loader = build_dataset(config.batch_size)
        network = build_network(config.fc_layer_size, config.dropout)
        optimizer = build_optimizer(network, config.optimizer, config.learning_rate)

        for epoch in range(config.epochs):
            avg_loss = train_epoch(network, loader, optimizer)
            wandb.log({"loss": avg_loss, "epoch": epoch})

# %%
def build_dataset(batch_size):
   
    transform = transforms.Compose(
        [transforms.ToTensor(),
         transforms.Normalize((0.1307,), (0.3081,))])
    # download MNIST training dataset
    dataset = datasets.MNIST(".", train=True, download=True,
                             transform=transform)
    sub_dataset = torch.utils.data.Subset(
        dataset, indices=range(0, len(dataset), 5))
    loader = torch.utils.data.DataLoader(sub_dataset, batch_size=batch_size)

    return loader


def build_network(fc_layer_size, dropout):
    network = nn.Sequential(  # fully-connected, single hidden layer
        nn.Flatten(),
        nn.Linear(784, fc_layer_size), nn.ReLU(),
        nn.Dropout(dropout),
        nn.Linear(fc_layer_size, 10),
        nn.LogSoftmax(dim=1))

    return network.to(device)
        

def build_optimizer(network, optimizer, learning_rate):
    if optimizer == "sgd":
        optimizer = optim.SGD(network.parameters(),
                              lr=learning_rate, momentum=0.9)
    elif optimizer == "adam":
        optimizer = optim.Adam(network.parameters(),
                               lr=learning_rate)
    return optimizer


def train_epoch(network, loader, optimizer):
    cumu_loss = 0
    for _, (data, target) in enumerate(loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()

        # ➡ Forward pass
        loss = F.nll_loss(network(data), target)
        cumu_loss += loss.item()

        # ⬅ Backward pass + weight update
        loss.backward()
        optimizer.step()

        wandb.log({"batch loss": loss.item()})

    return cumu_loss / len(loader)

# %%
wandb.agent(sweep_id, train, count=5)
# Out:
# wandb: Agent Starting Run: 44yywpzd with config:
# wandb: 	batch_size: 35
# wandb: 	dropout: 0.4
# wandb: 	epochs: 1
# wandb: 	fc_layer_size: 512
# wandb: 	learning_rate: 0.06901555183996108
# wandb: 	optimizer: adam
#                     Syncing run <strong><a href="https://wandb.ai/chowk/pytorch-sweeps-demo/runs/44yywpzd" target="_blank">sweet-sweep-1</a></strong> to <a href="https://wandb.ai/chowk/pytorch-sweeps-demo" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Sweep page: <a href="https://wandb.ai/chowk/pytorch-sweeps-demo/sweeps/k9vnqmd5" target="_blank">https://wandb.ai/chowk/pytorch-sweeps-demo/sweeps/k9vnqmd5</a><br/>
# <br/>Waiting for W&B process to finish, PID 1824... <strong style="color:green">(success).</strong>
# ...
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
# ...
